# %%
NAME = "DUCROCQ Romain"

# %% [markdown]
# # Homework Week 5 - Questions
# # SQLite, join and merge tables

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import pymysql
import sqlite3

# %%
conn = sqlite3.connect('data/chinook.db')

# %%
QUERY = "SELECT * FROM sqlite_master WHERE type = 'table'"
df = pd.read_sql(QUERY, conn)
df
# Out:
#      type             name         tbl_name  rootpage  \
# 0   table           albums           albums         2
# 1   table  sqlite_sequence  sqlite_sequence         3
# 2   table          artists          artists         4
# 3   table        customers        customers         5
# 4   table        employees        employees         8
# 5   table           genres           genres        10
# 6   table         invoices         invoices        11
# 7   table    invoice_items    invoice_items        13
# 8   table      media_types      media_types        15
# 9   table        playlists        playlists        16
# 10  table   playlist_track   playlist_track        17
# 11  table           tracks           tracks        20
# 12  table     sqlite_stat1     sqlite_stat1       864
#
#                                                   sql
# 0   CREATE TABLE "albums"\r\n(\r\n    [AlbumId] IN...
# 1              CREATE TABLE sqlite_sequence(name,seq)
# 2   CREATE TABLE "artists"\r\n(\r\n    [ArtistId] ...
# 3   CREATE TABLE "customers"\r\n(\r\n    [Customer...
# 4   CREATE TABLE "employees"\r\n(\r\n    [Employee...
# 5   CREATE TABLE "genres"\r\n(\r\n    [GenreId] IN...
# 6   CREATE TABLE "invoices"\r\n(\r\n    [InvoiceId...
# 7   CREATE TABLE "invoice_items"\r\n(\r\n    [Invo...
# 8   CREATE TABLE "media_types"\r\n(\r\n    [MediaT...
# 9   CREATE TABLE "playlists"\r\n(\r\n    [Playlist...
# 10  CREATE TABLE "playlist_track"\r\n(\r\n    [Pla...
# 11  CREATE TABLE "tracks"\r\n(\r\n    [TrackId] IN...
# 12            CREATE TABLE sqlite_stat1(tbl,idx,stat)

# %% [markdown]
# ## Save the artists, albums and tracks tables in three different dataframes with clear names

# %%
artists = pd.read_sql("SELECT * FROM artists", conn)
artists
# Out:
#      ArtistId                                               Name
# 0           1                                              AC/DC
# 1           2                                             Accept
# 2           3                                          Aerosmith
# 3           4                                  Alanis Morissette
# 4           5                                    Alice In Chains
# ..        ...                                                ...
# 270       271   Mela Tenenbaum, Pro Musica Prague & Richard Kapp
# 271       272                             Emerson String Quartet
# 272       273  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 273       274                                      Nash Ensemble
# 274       275                              Philip Glass Ensemble
#
# [275 rows x 2 columns]

# %%
albums = pd.read_sql("SELECT * FROM albums", conn)
albums
# Out:
#      AlbumId                                              Title  ArtistId
# 0          1              For Those About To Rock We Salute You         1
# 1          2                                  Balls to the Wall         2
# 2          3                                  Restless and Wild         2
# 3          4                                  Let There Be Rock         1
# 4          5                                           Big Ones         3
# ..       ...                                                ...       ...
# 342      343                             Respighi:Pines of Rome       226
# 343      344  Schubert: The Late String Quartets & String Qu...       272
# 344      345                                Monteverdi: L'Orfeo       273
# 345      346                              Mozart: Chamber Music       274
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...       275
#
# [347 rows x 3 columns]

# %%
tracks = pd.read_sql("SELECT * FROM tracks", conn)
tracks
# Out:
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# 0               1        1          Angus Young, Malcolm Young, Brian Johnson
# 1               2        1                                               None
# 2               2        1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...
# 3               2        1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...
# 4               2        1                         Deaffy & R.A. Smith-Diesel
# ...           ...      ...                                                ...
# 3498            2       24                                               None
# 3499            2       24                                     Franz Schubert
# 3500            2       24                                 Claudio Monteverdi
# 3501            2       24                            Wolfgang Amadeus Mozart
# 3502            2       10                                       Philip Glass
#
#       Milliseconds     Bytes  UnitPrice
# 0           343719  11170334       0.99
# 1           342562   5510424       0.99
# 2           230619   3990994       0.99
# 3           252051   4331779       0.99
# 4           375418   6290521       0.99
# ...            ...       ...        ...
# 3498        286741   4718950       0.99
# 3499        139200   2283131       0.99
# 3500         66639   1189062       0.99
# 3501        221331   3665114       0.99
# 3502        206005   3305164       0.99
#
# [3503 rows x 9 columns]

# %% [markdown]
# ## Join artists and albums tables in two ways, using an SQL statement in pandas

# %%
QUERY_1 = "SELECT artists.ArtistId, AlbumId, Title, Name FROM albums LEFT OUTER JOIN artists ON albums.ArtistId = artists.ArtistID"
QUERY_2 = "SELECT * FROM albums INNER JOIN artists ON albums.ArtistId = artists.ArtistID"

artists_albums_1 = pd.read_sql(QUERY_1, conn)
artists_albums_2 = pd.read_sql(QUERY_2, conn)

artists_albums_1
# Out:
#      ArtistId  AlbumId                                              Title  \
# 0           1        1              For Those About To Rock We Salute You
# 1           2        2                                  Balls to the Wall
# 2           2        3                                  Restless and Wild
# 3           1        4                                  Let There Be Rock
# 4           3        5                                           Big Ones
# ..        ...      ...                                                ...
# 342       226      343                             Respighi:Pines of Rome
# 343       272      344  Schubert: The Late String Quartets & String Qu...
# 344       273      345                                Monteverdi: L'Orfeo
# 345       274      346                              Mozart: Chamber Music
# 346       275      347  Koyaanisqatsi (Soundtrack from the Motion Pict...
#
#                                                   Name
# 0                                                AC/DC
# 1                                               Accept
# 2                                               Accept
# 3                                                AC/DC
# 4                                            Aerosmith
# ..                                                 ...
# 342                                     Eugene Ormandy
# 343                             Emerson String Quartet
# 344  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 345                                      Nash Ensemble
# 346                              Philip Glass Ensemble
#
# [347 rows x 4 columns]

# %% [markdown]
# ## Create a PivotTable showing for each artist, his/her/their albums (the titles), and for each album the duration
# 2 levels expected in the hierarchical index.
#
# Hint : Use the table tracks and the df created in Q2.

# %%
artists_albums_durations = pd.merge(artists_albums_1, tracks[['AlbumId', 'Milliseconds']].groupby(['AlbumId']).sum(),how='left', on='AlbumId')
pivot_artists_albums_durations = artists_albums_durations.pivot_table(values='Milliseconds', index=['Name', 'Title'])
pivot_artists_albums_durations
# Out:
#                                                                                           Milliseconds
# Name                                               Title
# AC/DC                                              For Those About To Rock We Salute You       2400415
#                                                    Let There Be Rock                           2453259
# Aaron Copland & London Symphony Orchestra          A Copland Celebration, Vol. I                198064
# Aaron Goldberg                                     Worlds                                       266936
# Academy of St. Martin in the Fields & Sir Nevil... The World of Classical Favourites            465201
# ...                                                                                                ...
# Vinícius De Moraes                                 Vinicius De Moraes                          3254721
# Wilhelm Kempff                                     Bach: Goldberg Variations                    120463
# Yehudi Menuhin                                     Bartok: Violin & Viola Concertos             299350
# Yo-Yo Ma                                           Bach: The Cello Suites                       143288
# Zeca Pagodinho                                     Ao Vivo [IMPORT]                            4065140
#
# [347 rows x 1 columns]

# %% [markdown]
# ## Plot a decreasing bar char showing the top 20 albums by duration

# %%
pivot_artists_albums_durations.sort_values('Milliseconds',ascending=False).head(20).plot(kind='bar', figsize = (20,10))

# %% [markdown]
# ## Select only  CustomerId and email from customers table using pd.read_sql_query()

# %%
cutomer_emails = pd.read_sql_query("SELECT CustomerId, Email FROM customers", conn)
cutomer_emails
# Out:
#     CustomerId                          Email
# 0            1           luisg@embraer.com.br
# 1            2          leonekohler@surfeu.de
# 2            3            ftremblay@gmail.com
# 3            4          bjorn.hansen@yahoo.no
# 4            5       frantisekw@jetbrains.com
# 5            6                hholy@gmail.com
# 6            7         astrid.gruber@apple.at
# 7            8          daan_peeters@apple.be
# 8            9          kara.nielsen@jubii.dk
# 9           10       eduardo@woodstock.com.br
# 10          11               alero@uol.com.br
# 11          12  roberto.almeida@riotur.gov.br
# 12          13       fernadaramos4@uol.com.br
# 13          14             mphilips12@shaw.ca
# 14          15            jenniferp@rogers.ca
# 15          16             fharris@google.com
# 16          17        jacksmith@microsoft.com
# 17          18              michelleb@aol.com
# 18          19               tgoyer@apple.com
# 19          20            dmiller@comcast.com
# 20          21            kachase@hotmail.com
# 21          22             hleacock@gmail.com
# 22          23         johngordon22@yahoo.com
# 23          24             fralston@gmail.com
# 24          25             vstevens@yahoo.com
# 25          26       ricunningham@hotmail.com
# 26          27           patrick.gray@aol.com
# 27          28            jubarnett@gmail.com
# 28          29               robbrown@shaw.ca
# 29          30            edfrancis@yachoo.ca
# 30          31           marthasilk@gmail.com
# 31          32         aaronmitchell@yahoo.ca
# 32          33         ellie.sullivan@shaw.ca
# 33          34            jfernandes@yahoo.pt
# 34          35              masampaio@sapo.pt
# 35          36      hannah.schneider@yahoo.de
# 36          37           fzimmermann@yahoo.de
# 37          38            nschroder@surfeu.de
# 38          39       camille.bernard@yahoo.fr
# 39          40    dominiquelefebvre@gmail.com
# 40          41        marc.dubois@hotmail.com
# 41          42          wyatt.girard@yahoo.fr
# 42          43      isabelle_mercier@apple.fr
# 43          44      terhi.hamalainen@apple.fi
# 44          45       ladislav_kovacs@apple.hu
# 45          46           hughoreilly@apple.ie
# 46          47         lucas.mancini@yahoo.it
# 47          48        johavanderberg@yahoo.nl
# 48          49         stanisław.wójcik@wp.pl
# 49          50         enrique_munoz@yahoo.es
# 50          51      joakim.johansson@yahoo.se
# 51          52         emma_jones@hotmail.com
# 52          53          phil.hughes@gmail.com
# 53          54          steve.murray@yahoo.uk
# 54          55           mark.taylor@yahoo.au
# 55          56       diego.gutierrez@yahoo.ar
# 56          57             luisrojas@yahoo.cl
# 57          58        manoj.pareek@rediff.com
# 58          59       puja_srivastava@yahoo.in

# %% [markdown]
# ## Select only  CustomerId and email from customers table  with country = USA using pd.read_sql_query()

# %%
cutomer_emails_usa = pd.read_sql_query("SELECT CustomerId, Email FROM customers WHERE Country='USA'", conn)
cutomer_emails_usa
# Out:
#     CustomerId                     Email
# 0           16        fharris@google.com
# 1           17   jacksmith@microsoft.com
# 2           18         michelleb@aol.com
# 3           19          tgoyer@apple.com
# 4           20       dmiller@comcast.com
# 5           21       kachase@hotmail.com
# 6           22        hleacock@gmail.com
# 7           23    johngordon22@yahoo.com
# 8           24        fralston@gmail.com
# 9           25        vstevens@yahoo.com
# 10          26  ricunningham@hotmail.com
# 11          27      patrick.gray@aol.com
# 12          28       jubarnett@gmail.com

# %% [markdown]
# ## Select CustomerId, Total from invoices with the ten most important totals

# %%
top_10_invoices = pd.read_sql_query("SELECT CustomerId, Total FROM invoices ORDER BY Total DESC LIMIT 10", conn)
top_10_invoices
# Out:
#    CustomerId  Total
# 0           6  25.86
# 1          26  23.86
# 2          45  21.86
# 3          46  21.86
# 4           7  18.86
# 5          25  18.86
# 6          57  17.91
# 7           5  16.86
# 8          43  16.86
# 9          24  15.86

# %% [markdown]
# ## Merge the two dataframes created in Q7 and Q8 by CustomerId
# Study the different way of merging : inner, left and right

# %%
top_invoices_usa_emails = pd.merge(top_10_invoices, cutomer_emails_usa, how='inner', on='CustomerId')
top_invoices_usa_emails
# Out:
#    CustomerId  Total                     Email
# 0          26  23.86  ricunningham@hotmail.com
# 1          25  18.86        vstevens@yahoo.com
# 2          24  15.86        fralston@gmail.com
